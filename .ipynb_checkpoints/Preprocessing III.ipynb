# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Extracting 2018 Movies

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header = 0)[2]
df2 = pd.read_html(link, header = 0)[3]
df3 = pd.read_html(link, header = 0)[4]
df4 = pd.read_html(link, header = 0)[5]

# %%
#Appending to get data from JAN to DEC.
movies_2018 = df1.append(df2.append(df3.append(df4,ignore_index = True),ignore_index = True),ignore_index =True)

# %%
movies_2018
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
def get_director(x):
    if ' (director)' in x:
        return x.split(" (director)")[0]
    elif ' (directors)' in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
movies_2018['director_name'] = movies_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor_1_name(x):
    return (x.split("y); ")[-1].split(", ")[0])

# %%
movies_2018['actor_1_name'] = movies_2018['Cast and crew'].map(lambda x: get_actor_1_name(x))

# %%
def get_actor_2_name(x):
    if len((x.split("y); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("y); ")[-1]).split(", ")[1])

# %%
movies_2018['actor_2_name'] = movies_2018['Cast and crew'].map(lambda x: get_actor_2_name(x))

# %%
movies_2018.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
def get_actor_3_name(x):
    if len(x.split("y); ")[-1].split(", ")) < 3:
        return np.NaN
    else:
        return (x.split("y); ")[-1].split(", ")[2])

# %%
movies_2018['actor_3_name'] = movies_2018['Cast and crew'].map(lambda x: get_actor_3_name(x))

# %%
movies_2018.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '83c52c49ddee44475891ab5d3a3e5a3d'
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
movies_2018['genres'] = movies_2018['Title'].map(lambda x: get_genre(str(x)))

# %%
movies_2018.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
movies_2018.rename(columns = {"Title":"movie_title"},inplace = True)

# %%
movies_2018['movie_title'] = movies_2018['movie_title'].str.lower()

# %%
movies_2018 = movies_2018.loc[:,['genres','movie_title','actor_1_name','actor_2_name','actor_3_name','director_name']]

# %%
movies_2018['tags'] = movies_2018['genres'] + " "+ movies_2018['movie_title']+ " "+movies_2018['actor_1_name']+" "+movies_2018['actor_2_name']+" "+movies_2018['actor_3_name']+" "+movies_2018['director_name']

# %%
movies_2018.head()
# Out:
#                     genres              movie_title    actor_1_name  \
# 0  Horror Mystery Thriller  insidious: the last key       Lin Shaye
# 1           Thriller Drama         the strange ones   Alex Pettyfer
# 2          Action Thriller                 stratton  Dominic Cooper
# 3    Drama History Western            sweet country     Bryan Brown
# 4  Action Thriller Mystery             the commuter     Liam Neeson
#
#              actor_2_name    actor_3_name       director_name  \
# 0           Angus Sampson  Leigh Whannell        Adam Robitel
# 1  James Freedson-Jackson   Emily Althaus    Lauren Wolkstein
# 2          Austin Stowell      Gemma Chan          Simon West
# 3               Sam Neill             NaN    Warwick Thornton
# 4            Vera Farmiga  Patrick Wilson  Jaume Collet-Serra
#
#                                                 tags
# 0  Horror Mystery Thriller insidious: the last ke...
# 1  Thriller Drama the strange ones Alex Pettyfer ...
# ...

# %% [markdown]
# ## Extracting 2019 Movies

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header = 0)[2]
df2 = pd.read_html(link, header = 0)[3]
df3 = pd.read_html(link, header = 0)[4]
df4 = pd.read_html(link, header = 0)[5]

movies_2019 = df1.append(df2.append(df3.append(df4, ignore_index = True), ignore_index = True), ignore_index = True)

# %%
movies_2019.head()
# Out:
#    Opening  Opening.1             Title                 Production company  \
# 0  JANUARY          4       Escape Room  Columbia Pictures / Original Film
# 1  JANUARY          4        Rust Creek                          IFC Films
# 2  JANUARY          4  American Hangman        Hangman Justice Productions
# 3  JANUARY         11  A Dog's Way Home                  Columbia Pictures
# 4  JANUARY         11        The Upside                  STX Entertainment
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]

# %%
movies_2019['director_name'] = movies_2019['Cast and crew'].map(lambda x: get_director(x))

# %%
movies_2019['actor_1_name'] = movies_2019['Cast and crew'].map(lambda x: get_actor_1_name(x))

# %%
movies_2019['actor_2_name'] = movies_2019['Cast and crew'].map(lambda x: get_actor_2_name(x))

# %%
movies_2019['actor_3_name'] = movies_2019['Cast and crew'].map(lambda x: get_actor_3_name(x))

# %%
movies_2019['genres'] = movies_2019['Title'].map(lambda x: get_genre(str(x)))

# %%
movies_2019.head()
# Out:
#    Opening  Opening.1             Title                 Production company  \
# 0  JANUARY          4       Escape Room  Columbia Pictures / Original Film
# 1  JANUARY          4        Rust Creek                          IFC Films
# 2  JANUARY          4  American Hangman        Hangman Justice Productions
# 3  JANUARY         11  A Dog's Way Home                  Columbia Pictures
# 4  JANUARY         11        The Upside                  STX Entertainment
#
#                                        Cast and crew Ref.  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]
#
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# ...

# %%
movies_2019.rename(columns = {"Title":"movie_title"},inplace = True)

# %%
movies_2019['movie_title'] = movies_2019['movie_title'].str.lower()

# %%
movies_2019 = movies_2019.loc[:,['genres','movie_title','actor_1_name','actor_2_name','actor_3_name','director_name']]

# %%
movies_2019['tags'] = movies_2019['genres'] + " "+ movies_2019['movie_title']+ " "+movies_2019['actor_1_name']+" "+movies_2019['actor_2_name']+" "+movies_2019['actor_3_name']+" "+movies_2019['director_name']

# %%
movies_2019.head()
# Out:
#                     genres       movie_title         actor_1_name  \
# 0  Horror Thriller Mystery       escape room       Taylor Russell
# 1           Thriller Drama        rust creek    Hermione Corfield
# 2                 Thriller  american hangman    Donald Sutherland
# 3   Drama Adventure Family  a dog's way home  Bryce Dallas Howard
# 4             Comedy Drama        the upside       Bryan Cranston
#
#          actor_2_name      actor_3_name         director_name  \
# 0        Logan Miller  Deborah Ann Woll          Adam Robitel
# 1         Jay Paulson      Sean O'Bryan           Jen McGowan
# 2  Vincent Kartheiser     Oliver Dennis     Wilson Coneybeare
# 3  Edward James Olmos   Alexandra Shipp  Charles Martin Smith
# 4          Kevin Hart     Nicole Kidman           Neil Burger
#
#                                                 tags
# 0  Horror Thriller Mystery escape room Taylor Rus...
# 1  Thriller Drama rust creek Hermione Corfield Ja...
# ...

# %%
movies_2018.isna().sum()
# Out:
# genres            2
# movie_title       0
# actor_1_name      0
# actor_2_name     10
# actor_3_name     27
# director_name     0
# tags             29
# dtype: int64

# %%
movies_2018.dropna(how = 'any', inplace = True)

# %%
movies_2019.isna().sum()
# Out:
# genres            0
# movie_title       0
# actor_1_name      0
# actor_2_name      1
# actor_3_name     15
# director_name     0
# tags             15
# dtype: int64

# %%
movies_2019.dropna(how = 'any',inplace = True)

# %%
movies_2018_19 = movies_2018.append(movies_2019, ignore_index = True)

# %%
movies_till_2017 = pd.read_csv('datasets/movies_till_2017.csv')

# %%
movies_till_2019 = movies_till_2017.append(movies_2018_19, ignore_index = True)

# %%
#Saving movies till 2019's details into CSV format. 
movies_2018_19.to_csv('movies_till_2019.csv', index = False)
